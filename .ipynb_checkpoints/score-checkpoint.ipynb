# %%
import pandas as pd

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
marked_data_vn=pd.read_csv('marked_data_vn.csv')

# %%
marked_data_vn.head(2)
# Out:
#      _id      companies
# 0   42.0             []
# 1  110.0  ['Sensetime']

# %%
run_op_v1=pd.read_csv('run_op_v1.csv')

# %%
run_op_v1
# Out:
#      _id                               identified_companies
# 0      1                   ['Tesla Motors', 'Xpeng Motors']
# 1      2                                                 []
# 2      3                                   ['XCMG Company']
# 3      4                    ['United Community Banks Ltd.']
# 4      5                 ['Eventbrite', 'Golden West Food']
# ..   ...                                                ...
# 108  109                                        ['AlloVir']
# 109  110                                                 []
# 110  111  ['Minerals Technologies Inc.', 'Corsair Capita...
# 111  112        ['Golden West Food', 'Corsair Capital LLC']
# 112  113  ['Minerals Technologies Inc.', 'Checkmate Phar...
#
# [113 rows x 2 columns]

# %%
score_raw_v1=marked_data_vn.merge(run_op_v1,how='left')
from ast import literal_eval
score_raw_v1['identified_companies']=score_raw_v1['identified_companies'].apply(literal_eval)
score_raw_v1['companies']=score_raw_v1['companies'].apply(literal_eval)
score_raw_v1.loc[:,'companies']=score_raw_v1['companies'].apply(lambda x: sorted(x))
score_raw_v1.loc[:,'identified_companies']=score_raw_v1.apply(lambda x: sorted(x['identified_companies']),axis=1)

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
# le.fit(["paris", "paris", "tokyo", "amsterdam"])

# %%
score_raw_v1
# Out:
#       _id                                     companies  \
# 0    42.0                                            []
# 1   110.0                                   [Sensetime]
# 2    38.0                                  [Telefónica]
# 3    17.0                                      [Nvidia]
# 4   111.0                                            []
# 5    11.0                                            []
# 6    84.0                                            []
# 7    23.0                                            []
# 8    94.0                                            []
# 9     4.0                 [United Community Banks Ltd.]
# 10   65.0                                            []
# 11   18.0                              [Alta Equipment]
# 12   14.0                        [Microsft.com, Tiktok]
# 13   95.0                                            []
# 14   31.0                        [Microsft.com, Tiktok]
# 15   16.0                        [Microsft.com, Tiktok]
# 16   87.0                                            []
# 17   25.0                          [Amplitude Surgical]
# 18   44.0                                            []
# 19   27.0                        [Microsft.com, Tiktok]
# 20   86.0                                            []
# 21   91.0                              [Domino's Pizza]
# 22   78.0                                        [Amul]
# 23   50.0                                            []
# 24  112.0                                            []
# 25    3.0                                            []
# 26   10.0                                            []
# 27   48.0                                            []
# 28   32.0                        [Microsft.com, Tiktok]
# 29   39.0                   [Corsair Capital LLC, MSTS]
# 30   49.0                                [XCMG Company]
# 31    7.0                                    [XBiotech]
# 32  102.0                    [Marvell Technology Group]
# 33  103.0                                            []
# 34   74.0                                            []
# 35   76.0                                    [Dominion]
# 36   19.0                              [Alta Equipment]
# 37   41.0  [Franklin Templeton Investments, Legg Mason]
# 38   37.0                                      [Nvidia]
# 39    2.0                                        [Wine]
# 40   80.0                                            []
# 41  107.0                   [Checkmate Pharmaceuticals]
# 42   72.0                                      [Tiktok]
# 43   28.0                                            []
# 44   20.0                                            []
# 45   88.0                              [Domino's Pizza]
# 46   99.0                                            []
# 47   58.0                                         [NIH]
# 48   97.0                                            []
# 49   96.0                                            []
# 50   70.0                                            []
# 51   61.0          [Compulink Technologies, Freshworks]
# 52   52.0                                            []
# 53    1.0                  [Tesla Motors, Xpeng Motors]
# 54   56.0                  [Minerals Technologies Inc.]
# 55   62.0                                            []
#
#                                  identified_companies
# 0                                                  []
# 1                                                  []
# 2                                        [Telefónica]
# 3                                            [Nvidia]
# 4   [Corsair Capital LLC, Minerals Technologies Inc.]
# 5                                                  []
# 6                                        [Freshworks]
# 7   [Bridge stone, Marvell Technology Group, Nvidi...
# 8     [Corsair Capital LLC, Marvell Technology Group]
# 9                       [United Community Banks Ltd.]
# 10                                                 []
# 11                                   [Alta Equipment]
# 12                             [Microsft.com, Tiktok]
# 13                                           [Nordea]
# 14                             [Microsft.com, Tiktok]
# 15                                     [Microsft.com]
# 16                             [Fidelity Investments]
# 17                               [Amplitude Surgical]
# 18                                                 []
# 19                             [Microsft.com, Tiktok]
# 20                                                 []
# 21   [Dominion, Domino's Pizza, Fidelity Investments]
# 22                                             [Amul]
# 23                                                 []
# 24            [Corsair Capital LLC, Golden West Food]
# 25                                     [XCMG Company]
# 26  [Minerals Technologies Inc., United Community ...
# 27                                                 []
# 28                             [Microsft.com, Tiktok]
# 29      [Compulink Technologies, Corsair Capital LLC]
# 30                                     [XCMG Company]
# 31                                         [XBiotech]
# 32         [Domino's Pizza, Marvell Technology Group]
# 33                                                 []
# 34                       [Minerals Technologies Inc.]
# 35                                         [Dominion]
# 36                                   [Alta Equipment]
# 37       [Franklin Templeton Investments, Legg Mason]
# 38                                [Nvidia, Sensetime]
# 39                                                 []
# 40                                                 []
# 41                        [Checkmate Pharmaceuticals]
# 42                                           [Tiktok]
# 43  [Corsair Capital LLC, Minerals Technologies Inc.]
# 44          [Checkmate Pharmaceuticals, Microsft.com]
# 45                                   [Domino's Pizza]
# 46                                                 []
# 47                                              [NIH]
# 48                    [Catalant, Corsair Capital LLC]
# 49                                           [Gencor]
# 50                                             [MSTS]
# 51               [Compulink Technologies, Freshworks]
# 52                                                 []
# 53                       [Tesla Motors, Xpeng Motors]
# 54                       [Minerals Technologies Inc.]
# 55         [Compulink Technologies, TTM Technologies]
